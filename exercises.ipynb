# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenngochieu3127/git-practice/blob/main/exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
data = {
    "evolution": ["Ivysaur", "Charmeleon", "Wartortle", "Metapod"],
    "hp": [45, 39, 44, 45],
    "name": ["Bulbasaur", "Charmander", "Squirtle", "Caterpie"],
    "pokedex": ["yes", "no", "yes", "no"],
}

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
pokemon = pd.DataFrame(data)

pokemon
# Out:
#     evolution  hp        name pokedex
# 0     Ivysaur  45   Bulbasaur     yes
# 1  Charmeleon  39  Charmander      no
# 2   Wartortle  44    Squirtle     yes
# 3     Metapod  45    Caterpie      no

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[["name", "hp", "evolution", "pokedex"]]

pokemon
# Out:
#          name  hp   evolution pokedex
# 0   Bulbasaur  45     Ivysaur     yes
# 1  Charmander  39  Charmeleon      no
# 2    Squirtle  44   Wartortle     yes
# 3    Caterpie  45     Metapod      no

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon["place"] = ["Forest", "Mountain", "Lake", "Garden"]

pokemon
# Out:
# /tmp/ipykernel_1718/3433724252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pokemon["place"] = ["Forest", "Mountain", "Lake", "Garden"]
#          name  hp   evolution pokedex     place
# 0   Bulbasaur  45     Ivysaur     yes    Forest
# 1  Charmander  39  Charmeleon      no  Mountain
# 2    Squirtle  44   Wartortle     yes      Lake
# 3    Caterpie  45     Metapod      no    Garden

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
pokemon.dtypes
# Out:
# name         object
# hp            int64
# evolution    object
# pokedex      object
# place        object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
len(pokemon)
# Out:
# 4
